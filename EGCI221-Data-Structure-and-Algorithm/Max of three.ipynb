# %%
def max_of_three(x,y,z):
  l = []
  l.append(x); l.append(y); l.append(z)
  l.sort()
  return(l[-1])
x,y,z = int(input()),int(input()),int(input())
max_of_three(x,y,z)
# Out:
# 19000
# 30
# 50
# 19000

# %%
print("Welcome to bill calculator!")
eat_alone = int(input("How many menu did you eat alone?\n"))
final=0
for i in range(eat_alone):
    price_single = int(input("Price: "))
    final += price_single
eat_share = int(input("How many menu did you eat with friends?\n"))
for i in range(eat_share):
  price_share = int(input("Price: ")
  share = int(input("How many people did you share with ?"))
  final += (price_share / people)
print(f"You have to pay {final} Bath")
# Out:
#   File "<ipython-input-13-283c0bc96656>", line 12
#     share = int(input("How many people did you share with ?"))
#         ^
# SyntaxError: invalid syntax
